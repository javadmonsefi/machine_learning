# %% [markdown]
# # Extremely Randomized Trees

# %%
# from google.colab import files
# up = files.upload()

# %% [markdown]
# ## import dataset

# %%
import pandas as pd
df = pd.read_csv('mydata.csv')
df.head(3)
# Out:
#    Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0   23    0   0            0   25.355  drugY
# 1   47    1   1            0   13.093  drugC
# 2   47    1   1            0   10.114  drugC

# %% [markdown]
# ## cleaning

# %%
# clean the data

# %% [markdown]
# ## encoding

# %%
# encode the data

# %% [markdown]
# ## define x , y

# %%
import numpy as np
x = df[['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K']].values
x[0:5]
# Out:
# array([[23.   ,  0.   ,  0.   ,  0.   , 25.355],
#        [47.   ,  1.   ,  1.   ,  0.   , 13.093],
#        [47.   ,  1.   ,  1.   ,  0.   , 10.114],
#        [28.   ,  0.   ,  2.   ,  0.   ,  7.798],
#        [61.   ,  0.   ,  1.   ,  0.   , 18.043]])

# %%
y = df['Drug']
y[:5]
# Out:
# 0    drugY
# 1    drugC
# 2    drugC
# 3    drugX
# 4    drugY
# Name: Drug, dtype: object

# %% [markdown]
# ## spliting

# %%
### finding best random state 

# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import ExtraTreesClassifier
# from sklearn.metrics import accuracy_score

# import time
# t1 = time.time()
# lst = []
# for i in range(1,10):
#     x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=i) 
#     etc = ExtraTreesClassifier(n_estimators=100, random_state=42)
#     etc.fit(x_train, y_train)
#     yhat_test = etc.predict(x_test)
#     acc = accuracy_score(y_test, yhat_test)
#     lst.append(acc)
# t2 = time.time()
# print(f"run time: {round((t2 - t1) / 60 , 0)} min")
# print(f"accuracy_score = {round(max(lst),2)}")
# print(f"random_state = {np.argmax(lst) + 1}")

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %% [markdown]
# ## scaling

# %%
# do not need for scaling

# %% [markdown]
# ## fit train data

# %%
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier(n_estimators=100, random_state=42)
etc.fit(x_train, y_train)
# Out:
# ExtraTreesClassifier(random_state=42)

# %% [markdown]
# ## predict test data

# %%
yhat_test = etc.predict(x_test)

# %% [markdown]
# ## Evaluate the model

# %%
from sklearn.metrics import accuracy_score
print("Accuracy_score (train data): ", accuracy_score(y_train, etc.predict(x_train)))
print("Accuracy_score (test data): ", accuracy_score(y_test, yhat_test))
# Out:
# Accuracy_score (train data):  1.0
# Accuracy_score (test data):  1.0

# %% [markdown]
# ## save the model

# %%
# import joblib
# joblib.dump(etc, 'etc_model.pkl')

# %% [markdown]
# ## load the model

# %%
# import joblib
# etc = joblib.load('etc_model.pkl')
